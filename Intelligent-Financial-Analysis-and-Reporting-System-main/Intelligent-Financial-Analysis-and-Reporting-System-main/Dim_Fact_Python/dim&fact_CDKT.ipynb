# %% [markdown]
# **BẢNG DIM**

# %%
import pandas as pd

# Dữ liệu bảng cân đối kế toán
table = {
    "TÀI SẢN": {
        "A - TÀI SẢN NGẮN HẠN": {
            "I. Tiền và các khoản tương đương tiền": {
                "Tiền": "111",
                "Các khoản tương đương tiền": "112"
            },
            "II. Đầu tư tài chính ngắn hạn": {
                "Chứng khoán kinh doanh": "121",
                "Dự phòng giảm giá chứng khoán kinh doanh (*)": "122",
                "Đầu tư nắm giữ đến ngày đáo hạn": "123"
            },
            "III. Các khoản phải thu ngắn hạn": {
                "Phải thu ngắn hạn của khách hàng": "131",
                "Trả trước cho người bán ngắn hạn": "132",
                "Phải thu nội bộ ngắn hạn": "133",
                "Phải thu theo tiến độ kế hoạch hợp đồng xây dựng": "134",
                "Phải thu về cho vay ngắn hạn": "135",
                "Phải thu ngắn hạn khác": "136",
                "Dự phòng phải thu ngắn hạn khó đòi (*)": "137",
                "Tài sản Thiếu chờ xử lý": "139"
            },
            "IV. Hàng tồn kho": {
                "Hàng tồn kho": "141",
                "Dự phòng giảm giá hàng tồn kho (*)": "149"
            },
            "V. Tài sản ngắn hạn khác": {
                "Chi phí trả trước ngắn hạn": "151",
                "Thuế GTGT được khấu trừ": "152",
                "Thuế và các khoản khác phải thu Nhà nước": "153",
                "Giao dịch mua bán lại trái phiếu Chính phủ": "154",
                "Tài sản ngắn hạn khác": "155"
            }
        },
        "B - TÀI SẢN DÀI HẠN": {
            "I. Các khoản phải thu dài hạn": {
                "Phải thu dài hạn của khách hàng": "211",
                "Trả trước cho người bán dài hạn": "212",
                "Vốn kinh doanh ở đơn vị trực thuộc": "213",
                "Phải thu nội bộ dài hạn": "214",
                "Phải thu về cho vay dài hạn": "215",
                "Phải thu dài hạn khác": "216",
                "Dự phòng phải thu dài hạn khó đòi (*)": "219"
            },
            "II. Tài sản cố định": {
                "Tài sản cố định hữu hình": {
                    "Nguyên giá": "222",
                    "Giá trị hao mòn luỹ kế (*)": "223"
                },
                "Tài sản cố định thuê tài chính": {
                    "Nguyên giá": "225",
                    "Giá trị hao mòn luỹ kế (*)": "226"
                },
                "Tài sản cố định vô hình": {
                    "Nguyên giá": "228",
                    "Giá trị hao mòn luỹ kế (*)": "229"
                },
                "Bất động sản đầu tư": {
                    "Nguyên giá": "231",
                    "Giá trị hao mòn luỹ kế (*)": "232"
                }
            },
            "III. Tài sản dở dang dài hạn": {
                "Chi phí sản xuất, kinh doanh dở dang dài hạn": "241",
                "Chi phí xây dựng cơ bản dở dang": "242"
            },
            "IV. Đầu tư tài chính dài hạn": {
                "Đầu tư vào công ty con": "251",
                "Đầu tư vào công ty liên doanh, liên kết": "252",
                "Đầu tư góp vốn vào đơn vị khác": "253",
                "Dự phòng đầu tư tài chính dài hạn (*)": "254",
                "Đầu tư nắm giữ đến ngày đáo hạn": "255"
            },
            "V. Tài sản dài hạn khác": {
                "Chi phí trả trước dài hạn": "261",
                "Tài sản thuế thu nhập hoãn lại": "262",
                "Thiết bị, vật tư, phụ tùng thay thế dài hạn": "263",
                "Tài sản dài hạn khác": "268"
            }
        },
        "TỔNG CỘNG TÀI SẢN (270 = 100 + 200)": "270"
    },
    "NGUỒN VỐN": {
        "C - NỢ PHẢI TRẢ": {
            "I. Nợ ngắn hạn": {
                "Phải trả người bán ngắn hạn": "311",
                "Người mua trả tiền trước ngắn hạn": "312",
                "Thuế và các khoản phải nộp Nhà nước": "313",
                "Phải trả người lao động": "314",
                "Chi phí phải trả ngắn hạn": "315",
                "Phải trả nội bộ ngắn hạn": "316",
                "Phải trả theo tiến độ kế hoạch hợp đồng xây dựng": "317",
                "Doanh thu chưa thực hiện ngắn hạn": "318",
                "Phải trả ngắn hạn khác": "319",
                "Vay và nợ thuê tài chính ngắn hạn": "320",
                "Dự phòng phải trả ngắn hạn": "321",
                "Quỹ khen thưởng, phúc lợi": "322",
                "Quỹ bình ổn giá": "323",
                "Giao dịch mua bán lại trái phiếu Chính phủ": "324"
            },
            "II. Nợ dài hạn": {
                "Phải trả người bán dài hạn": "331",
                "Người mua trả tiền trước dài hạn": "332",
                "Chi phí phải trả dài hạn": "333",
                "Phải trả nội bộ về vốn kinh doanh": "334",
                "Phải trả nội bộ dài hạn": "335",
                "Doanh thu chưa thực hiện dài hạn": "336",
                "Phải trả dài hạn khác": "337",
                "Vay và nợ thuê tài chính dài hạn": "338",
                "Trái phiếu chuyển đổi": "339",
                "Cổ phiếu ưu đãi": "340",
                "Thuế thu nhập hoãn lại phải trả": "341",
                "Dự phòng phải trả dài hạn": "342",
                "Quỹ phát triển khoa học và công nghệ": "343"
            }
        },
        "D - VỐN CHỦ SỞ HỮU": {
            "I. Vốn chủ sở hữu": {
                "Vốn góp của chủ sở hữu": {
                    "Cổ phiếu phổ thông có quyền biểu quyết": "411a",
                    "Cổ phiếu ưu đãi": "411b"
                },
                "Thặng dư vốn cổ phần": "412",
                "Quyền chọn chuyển đổi trái phiếu": "413",
                "Vốn khác của chủ sở hữu": "414",
                "Cổ phiếu quỹ (*)": "415",
                "Chênh lệch đánh giá lại tài sản": "416",
                "Chênh lệch tỷ giá hối đoái": "417",
                "Quỹ đầu tư phát triển": "418",
                "Quỹ hỗ trợ sắp xếp doanh nghiệp": "419",
                "Quỹ khác thuộc vốn chủ sở hữu": "420",
                "Lợi nhuận sau thuế chưa phân phối": {
                    "LNST chưa phân phối lũy kế đến cuối kỳ trước": "421a",
                    "LNST chưa phân phối kỳ này": "421b"
                },
                "Nguồn vốn đầu tư XDCB": "422"
            },
            "II. Nguồn kinh phí và quỹ khác": {
                "Nguồn kinh phí": "431",
                "Nguồn kinh phí đã hình thành TSCĐ": "432"
            }
        },
        "TỔNG CỘNG NGUỒN VỐN (440 = 300 + 400)": "440"
    }
}

def print_table(table, indent=0):
    for key, value in table.items():
        if isinstance(value, dict):
            print("\t" * indent + key)
            print_table(value, indent + 1)
        else:
            print("\t" * indent + f"{key}: {value}")

print_table(table)
# Out:
# TÀI SẢN
# 	A - TÀI SẢN NGẮN HẠN
# 		I. Tiền và các khoản tương đương tiền
# 			Tiền: 111
# 			Các khoản tương đương tiền: 112
# 		II. Đầu tư tài chính ngắn hạn
# 			Chứng khoán kinh doanh: 121
# 			Dự phòng giảm giá chứng khoán kinh doanh (*): 122
# 			Đầu tư nắm giữ đến ngày đáo hạn: 123
# 		III. Các khoản phải thu ngắn hạn
# 			Phải thu ngắn hạn của khách hàng: 131
# 			Trả trước cho người bán ngắn hạn: 132
# 			Phải thu nội bộ ngắn hạn: 133
# 			Phải thu theo tiến độ kế hoạch hợp đồng xây dựng: 134
# 			Phải thu về cho vay ngắn hạn: 135
# 			Phải thu ngắn hạn khác: 136
# 			Dự phòng phải thu ngắn hạn khó đòi (*): 137
# 			Tài sản Thiếu chờ xử lý: 139
# 		IV. Hàng tồn kho
# 			Hàng tồn kho: 141
# 			Dự phòng giảm giá hàng tồn kho (*): 149
# 		V. Tài sản ngắn hạn khác
# 			Chi phí trả trước ngắn hạn: 151
# 			Thuế GTGT được khấu trừ: 152
# 			Thuế và các khoản khác phải thu Nhà nước: 153
# 			Giao dịch mua bán lại trái phiếu Chính phủ: 154
# 			Tài sản ngắn hạn khác: 155
# ...

# %%
# import pandas as pd

# # Dữ liệu từ dictionary được chuyển đổi thành list các tuples
# data = []

# def flatten_dictionary(dictionary, prefix=''):
#     for key, value in dictionary.items():
#         if isinstance(value, dict):
#              flatten_dictionary(value, prefix + key + ' - ')
#         else:
#              data.append((prefix + key, value))

# flatten_dictionary(table)

# # Tạo DataFrame từ list dữ liệu
# df = pd.DataFrame(data, columns=['Chỉ tiêu', 'Mã số'])
# df
import pandas as pd

data = []

def flatten_dictionary(dictionary, prefix='', index=1):  # Thêm tham số index
    for key, value in dictionary.items():
        if isinstance(value, dict):
             flatten_dictionary(value, prefix + key + ' - ', index)  # Truyền index xuống đệ quy
        else:
             data.append((prefix + str(index) + '. ' + key, value))  # Thêm số thứ tự vào tên chỉ tiêu
             index += 1

flatten_dictionary(table)

# Tạo DataFrame từ list dữ liệu
df = pd.DataFrame(data, columns=['Chỉ tiêu', 'Mã số'])
df
# Out:
#                                              Chỉ tiêu Mã số
# 0   TÀI SẢN - A - TÀI SẢN NGẮN HẠN - I. Tiền và cá...   111
# 1   TÀI SẢN - A - TÀI SẢN NGẮN HẠN - I. Tiền và cá...   112
# 2   TÀI SẢN - A - TÀI SẢN NGẮN HẠN - II. Đầu tư tà...   121
# 3   TÀI SẢN - A - TÀI SẢN NGẮN HẠN - II. Đầu tư tà...   122
# 4   TÀI SẢN - A - TÀI SẢN NGẮN HẠN - II. Đầu tư tà...   123
# ..                                                ...   ...
# 86  NGUỒN VỐN - D - VỐN CHỦ SỞ HỮU - I. Vốn chủ sở...  421b
# 87  NGUỒN VỐN - D - VỐN CHỦ SỞ HỮU - I. Vốn chủ sở...   422
# 88  NGUỒN VỐN - D - VỐN CHỦ SỞ HỮU - II. Nguồn kin...   431
# 89  NGUỒN VỐN - D - VỐN CHỦ SỞ HỮU - II. Nguồn kin...   432
# 90  NGUỒN VỐN - 1. TỔNG CỘNG NGUỒN VỐN (440 = 300 ...   440
#
# [91 rows x 2 columns]

# %%
import pandas as pd

# Dữ liệu từ dictionary được chuyển đổi thành list các tuples
data = []

def flatten_dictionary(dictionary, prefix=''):
    for key, value in dictionary.items():
        if isinstance(value, dict):
            flatten_dictionary(value, prefix + key + ' - ')
        else:
            data.append((prefix[:-3], key, value))

flatten_dictionary(table)

# Tạo DataFrame từ list dữ liệu
df = pd.DataFrame(data, columns=['Level', 'Chỉ tiêu', 'Mã số'])

df
# Out:
#                                                 Level  \
# 0   TÀI SẢN - A - TÀI SẢN NGẮN HẠN - I. Tiền và cá...
# 1   TÀI SẢN - A - TÀI SẢN NGẮN HẠN - I. Tiền và cá...
# 2   TÀI SẢN - A - TÀI SẢN NGẮN HẠN - II. Đầu tư tà...
# 3   TÀI SẢN - A - TÀI SẢN NGẮN HẠN - II. Đầu tư tà...
# 4   TÀI SẢN - A - TÀI SẢN NGẮN HẠN - II. Đầu tư tà...
# ..                                                ...
# 86  NGUỒN VỐN - D - VỐN CHỦ SỞ HỮU - I. Vốn chủ sở...
# 87  NGUỒN VỐN - D - VỐN CHỦ SỞ HỮU - I. Vốn chủ sở...
# 88  NGUỒN VỐN - D - VỐN CHỦ SỞ HỮU - II. Nguồn kin...
# 89  NGUỒN VỐN - D - VỐN CHỦ SỞ HỮU - II. Nguồn kin...
# 90                                          NGUỒN VỐN
#
#                                         Chỉ tiêu Mã số
# 0                                           Tiền   111
# 1                     Các khoản tương đương tiền   112
# 2                         Chứng khoán kinh doanh   121
# 3   Dự phòng giảm giá chứng khoán kinh doanh (*)   122
# ...

# %%
import pandas as pd

# Dữ liệu bảng cân đối kế toán
table = {
    "TÀI SẢN": {
        "A - TÀI SẢN NGẮN HẠN": {
            "I. Tiền và các khoản tương đương tiền": {
                "Tiền": "111",
                "Các khoản tương đương tiền": "112"
            },
            "II. Đầu tư tài chính ngắn hạn": {
                "Chứng khoán kinh doanh": "121",
                "Dự phòng giảm giá chứng khoán kinh doanh (*)": "122",
                "Đầu tư nắm giữ đến ngày đáo hạn": "123"
            },
            "III. Các khoản phải thu ngắn hạn": {
                "Phải thu ngắn hạn của khách hàng": "131",
                "Trả trước cho người bán ngắn hạn": "132",
                "Phải thu nội bộ ngắn hạn": "133",
                "Phải thu theo tiến độ kế hoạch hợp đồng xây dựng": "134",
                "Phải thu về cho vay ngắn hạn": "135",
                "Phải thu ngắn hạn khác": "136",
                "Dự phòng phải thu ngắn hạn khó đòi (*)": "137",
                "Tài sản Thiếu chờ xử lý": "139"
            },
            "IV. Hàng tồn kho": {
                "Hàng tồn kho": "141",
                "Dự phòng giảm giá hàng tồn kho (*)": "149"
            },
            "V. Tài sản ngắn hạn khác": {
                "Chi phí trả trước ngắn hạn": "151",
                "Thuế GTGT được khấu trừ": "152",
                "Thuế và các khoản khác phải thu Nhà nước": "153",
                "Giao dịch mua bán lại trái phiếu Chính phủ": "154",
                "Tài sản ngắn hạn khác": "155"
            }
        },
        "B - TÀI SẢN DÀI HẠN": {
            "I. Các khoản phải thu dài hạn": {
                "Phải thu dài hạn của khách hàng": "211",
                "Trả trước cho người bán dài hạn": "212",
                "Vốn kinh doanh ở đơn vị trực thuộc": "213",
                "Phải thu nội bộ dài hạn": "214",
                "Phải thu về cho vay dài hạn": "215",
                "Phải thu dài hạn khác": "216",
                "Dự phòng phải thu dài hạn khó đòi (*)": "219"
            },
            "II. Tài sản cố định": {
                "Tài sản cố định hữu hình": {
                    "Nguyên giá": "222",
                    "Giá trị hao mòn luỹ kế (*)": "223"
                },
                "Tài sản cố định thuê tài chính": {
                    "Nguyên giá": "225",
                    "Giá trị hao mòn luỹ kế (*)": "226"
                },
                "Tài sản cố định vô hình": {
                    "Nguyên giá": "228",
                    "Giá trị hao mòn luỹ kế (*)": "229"
                },
                "Bất động sản đầu tư": {
                    "Nguyên giá": "231",
                    "Giá trị hao mòn luỹ kế (*)": "232"
                }
            },
            "III. Tài sản dở dang dài hạn": {
                "Chi phí sản xuất, kinh doanh dở dang dài hạn": "241",
                "Chi phí xây dựng cơ bản dở dang": "242"
            },
            "IV. Đầu tư tài chính dài hạn": {
                "Đầu tư vào công ty con": "251",
                "Đầu tư vào công ty liên doanh, liên kết": "252",
                "Đầu tư góp vốn vào đơn vị khác": "253",
                "Dự phòng đầu tư tài chính dài hạn (*)": "254",
                "Đầu tư nắm giữ đến ngày đáo hạn": "255"
            },
            "V. Tài sản dài hạn khác": {
                "Chi phí trả trước dài hạn": "261",
                "Tài sản thuế thu nhập hoãn lại": "262",
                "Thiết bị, vật tư, phụ tùng thay thế dài hạn": "263",
                "Tài sản dài hạn khác": "268"
            }
        },
        "TỔNG CỘNG TÀI SẢN (270 = 100 + 200)": "270"
    },
    "NGUỒN VỐN": {
        "C - NỢ PHẢI TRẢ": {
            "I. Nợ ngắn hạn": {
                "Phải trả người bán ngắn hạn": "311",
                "Người mua trả tiền trước ngắn hạn": "312",
                "Thuế và các khoản phải nộp Nhà nước": "313",
                "Phải trả người lao động": "314",
                "Chi phí phải trả ngắn hạn": "315",
                "Phải trả nội bộ ngắn hạn": "316",
                "Phải trả theo tiến độ kế hoạch hợp đồng xây dựng": "317",
                "Doanh thu chưa thực hiện ngắn hạn": "318",
                "Phải trả ngắn hạn khác": "319",
                "Vay và nợ thuê tài chính ngắn hạn": "320",
                "Dự phòng phải trả ngắn hạn": "321",
                "Quỹ khen thưởng, phúc lợi": "322",
                "Quỹ bình ổn giá": "323",
                "Giao dịch mua bán lại trái phiếu Chính phủ": "324"
            },
            "II. Nợ dài hạn": {
                "Phải trả người bán dài hạn": "331",
                "Người mua trả tiền trước dài hạn": "332",
                "Chi phí phải trả dài hạn": "333",
                "Phải trả nội bộ về vốn kinh doanh": "334",
                "Phải trả nội bộ dài hạn": "335",
                "Doanh thu chưa thực hiện dài hạn": "336",
                "Phải trả dài hạn khác": "337",
                "Vay và nợ thuê tài chính dài hạn": "338",
                "Trái phiếu chuyển đổi": "339",
                "Cổ phiếu ưu đãi": "340",
                "Thuế thu nhập hoãn lại phải trả": "341",
                "Dự phòng phải trả dài hạn": "342",
                "Quỹ phát triển khoa học và công nghệ": "343"
            }
        },
        "D - VỐN CHỦ SỞ HỮU": {
            "I. Vốn chủ sở hữu": {
                "Vốn góp của chủ sở hữu": {
                    "Cổ phiếu phổ thông có quyền biểu quyết": "411a",
                    "Cổ phiếu ưu đãi": "411b"
                },
                "Thặng dư vốn cổ phần": "412",
                "Quyền chọn chuyển đổi trái phiếu": "413",
                "Vốn khác của chủ sở hữu": "414",
                "Cổ phiếu quỹ (*)": "415",
                "Chênh lệch đánh giá lại tài sản": "416",
                "Chênh lệch tỷ giá hối đoái": "417",
                "Quỹ đầu tư phát triển": "418",
                "Quỹ hỗ trợ sắp xếp doanh nghiệp": "419",
                "Quỹ khác thuộc vốn chủ sở hữu": "420",
                "Lợi nhuận sau thuế chưa phân phối": {
                    "LNST chưa phân phối lũy kế đến cuối kỳ trước": "421a",
                    "LNST chưa phân phối kỳ này": "421b"
                },
                "Nguồn vốn đầu tư XDCB": "422"
            },
            "II. Nguồn kinh phí và quỹ khác": {
                "Nguồn kinh phí": "431",
                "Nguồn kinh phí đã hình thành TSCĐ": "432"
            }
        },
        "TỔNG CỘNG NGUỒN VỐN (440 = 300 + 400)": "440"
    }
}

def print_table(table, indent=0):
    for key, value in table.items():
        if isinstance(value, dict):
            print("\t" * indent + key)
            print_table(value, indent + 1)
        else:
            print("\t" * indent + f"{key}: {value}")

print_table(table)
# Out:
# TÀI SẢN
# 	A - TÀI SẢN NGẮN HẠN
# 		I. Tiền và các khoản tương đương tiền
# 			Tiền: 111
# 			Các khoản tương đương tiền: 112
# 		II. Đầu tư tài chính ngắn hạn
# 			Chứng khoán kinh doanh: 121
# 			Dự phòng giảm giá chứng khoán kinh doanh (*): 122
# 			Đầu tư nắm giữ đến ngày đáo hạn: 123
# 		III. Các khoản phải thu ngắn hạn
# 			Phải thu ngắn hạn của khách hàng: 131
# 			Trả trước cho người bán ngắn hạn: 132
# 			Phải thu nội bộ ngắn hạn: 133
# 			Phải thu theo tiến độ kế hoạch hợp đồng xây dựng: 134
# 			Phải thu về cho vay ngắn hạn: 135
# 			Phải thu ngắn hạn khác: 136
# 			Dự phòng phải thu ngắn hạn khó đòi (*): 137
# 			Tài sản Thiếu chờ xử lý: 139
# 		IV. Hàng tồn kho
# 			Hàng tồn kho: 141
# 			Dự phòng giảm giá hàng tồn kho (*): 149
# 		V. Tài sản ngắn hạn khác
# 			Chi phí trả trước ngắn hạn: 151
# 			Thuế GTGT được khấu trừ: 152
# 			Thuế và các khoản khác phải thu Nhà nước: 153
# 			Giao dịch mua bán lại trái phiếu Chính phủ: 154
# 			Tài sản ngắn hạn khác: 155
# ...

# %%
data = []

def flatten_dictionary(dictionary, prefix='', index=1):  # Thêm tham số index
    for key, value in dictionary.items():
        if isinstance(value, dict):
             flatten_dictionary(value, prefix + key + ' - ', index)  # Truyền index xuống đệ quy
        else:
             data.append((prefix + str(index) + '. ' + key, value))  # Thêm số thứ tự vào tên chỉ tiêu
             index += 1

flatten_dictionary(table)
# Tạo DataFrame từ list dữ liệu
df_dim = pd.DataFrame(data, columns=['Chỉ tiêu', 'Mã số'])
df_dim
# Out:
#                                              Chỉ tiêu Mã số
# 0   TÀI SẢN - A - TÀI SẢN NGẮN HẠN - I. Tiền và cá...   111
# 1   TÀI SẢN - A - TÀI SẢN NGẮN HẠN - I. Tiền và cá...   112
# 2   TÀI SẢN - A - TÀI SẢN NGẮN HẠN - II. Đầu tư tà...   121
# 3   TÀI SẢN - A - TÀI SẢN NGẮN HẠN - II. Đầu tư tà...   122
# 4   TÀI SẢN - A - TÀI SẢN NGẮN HẠN - II. Đầu tư tà...   123
# ..                                                ...   ...
# 86  NGUỒN VỐN - D - VỐN CHỦ SỞ HỮU - I. Vốn chủ sở...  421b
# 87  NGUỒN VỐN - D - VỐN CHỦ SỞ HỮU - I. Vốn chủ sở...   422
# 88  NGUỒN VỐN - D - VỐN CHỦ SỞ HỮU - II. Nguồn kin...   431
# 89  NGUỒN VỐN - D - VỐN CHỦ SỞ HỮU - II. Nguồn kin...   432
# 90  NGUỒN VỐN - 1. TỔNG CỘNG NGUỒN VỐN (440 = 300 ...   440
#
# [91 rows x 2 columns]

# %% [markdown]
# **BẢNG FACT**

# %%
# Đọc file Cân đối kế toán Quý 1
df1 = pd.read_excel('[aav] Quy1_can_doi_ke_toan.xlsx')
df2 = df_dim

# Xoá đi các dòng chứa toàn giá trị NaN
df1=df1.dropna(how='all')

# Đặt tên cho cột đầu tiên là chỉ tiêu
df1.columns = ['Chỉ tiêu'] + list(df1.columns[1:])

#  lọc các hàng của DataFrame df1 trong đó giá trị trong cột 'Chỉ tiêu' bắt đầu bằng một ký tự số
df1 = df1[df1['Chỉ tiêu'].str.match(r'^\d')]

# Loại bỏ kí tự (*)
df2 = df2.replace(' \(\*\)', '', regex=True)

# Lấy chuỗi kí tự cuối cùng sau dấu '-'
df2['Chỉ tiêu'] = df2['Chỉ tiêu'].str.split(' - ').str[-1]

# Gộp 2 dataframe theo chỉ tiêu
df_merged = pd.merge(df1, df2, on='Chỉ tiêu', how='outer')

# #Xoá cột "chỉ tiêu"
df_merged=df_merged.drop('Chỉ tiêu',axis=1)

# Sử dụng hàm melt()
df_merged = df_merged.melt(id_vars='Mã số', var_name='Quarter', value_name='value')

# Tách 'Quarter' thành 'year' và 'Quarter'
df_merged[['Quarter', 'year']] = df_merged['Quarter'].str.split(' - ', expand=True)

# Loại bỏ các ký tự không phải số trong cột 'Quarter'
df_merged['Quarter'] = df_merged['Quarter'].str.extract(r'(\d+)')

df_merged
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-b9e8c0499436> in <cell line: 2>()
#       1 # Đọc file Cân đối kế toán Quý 1
# ----> 2 df1 = pd.read_excel('[aav] Quy1_can_doi_ke_toan.xlsx')
#       3 df2 = df_dim
#       4
#       5 # Xoá đi các dòng chứa toàn giá trị NaN
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476     if not isinstance(io, ExcelFile):
#     477         should_close = True
# --> 478         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479     elif engine and engine != io.engine:
# ...

# %%
ten_file_excel = 'dim&fact.xlsx'

# Tên của sheet bạn muốn tạo trong file Excel
ten_sheet = 'dim_CDKT'

# Xuất DataFrame vào file Excel
with pd.ExcelWriter(ten_file_excel, engine='openpyxl', mode='a') as writer:
    df_dim.to_excel(writer, sheet_name=ten_sheet, index=False)

# %%
# Tên của file Excel bạn muốn sử dụng
ten_file_excel = 'dim&fact.xlsx'

# Tên của sheet bạn muốn thêm DataFrame mới
ten_sheet_moi = 'fact_CDKT'

# Ghi DataFrame thứ hai vào file Excel
with pd.ExcelWriter(ten_file_excel, engine='openpyxl', mode='a') as writer:
    df_merged.to_excel(writer, sheet_name=ten_sheet_moi, index=False)
